# %% [markdown]
# # **Introduction**
#
# Face Detection Systems have great uses in today’s world which demands security, accessibility or joy! Today, we will be building a model that can plot 15 key points on a face.
#
# Face Landmark Detection models form various features we see in social media apps. The face filters you find on Instagram are a common use case. The algorithm aligns the mask on the image keeping the face landmarks as base points.
#
# In this notebook, we'll develop a model which marks keypoints on a given image of a human face. We'll build a Convolutional Neural Network which takes an image and returns a array of keypoints.
#
# We'll require a GPU Hardware accelerator for training the model. Change the runtime type to GPU by going to Tools > Change Runtime Type > Hardware Accelerator > GPU.
#
# ![](https://miro.medium.com/max/2000/1*qNNr1hrFoaeAWru7VI0SbQ.png)

# %% [markdown]
# # **Reading data and Preprocessing**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
# Ploting images with landmarks
def plot_image_landmarks(img_array, df_landmarks, index):
    plt.imshow(img_array[index, :, :, 0], cmap = 'gray')
    plt.scatter(df_landmarks.iloc[index][0: -1: 2], df_landmarks.iloc[index][1: : 2], c = 'y')
    plt.show()

# %%
features = np.load('../input/face-images-with-marked-landmark-points/face_images.npz')
features = features.get(features.files[0]) # images
features = np.moveaxis(features, -1, 0)
features = features.reshape(features.shape[0], features.shape[1], features.shape[1], 1)

# %%
keypoints = pd.read_csv('../input/face-images-with-marked-landmark-points/facial_keypoints.csv')
keypoints.head()
# Out:
#    left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0          66.033564          39.002274           30.227008
# 1          64.332936          34.970077           29.949277
# 2          65.057053          34.909642           30.903789
# 3          65.225739          37.261774           32.023096
# 4          66.725301          39.621261           32.244810
#
#    right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0           36.421678                59.582075                39.647423
# 1           33.448715                58.856170                35.274349
# 2           34.909642                59.412000                36.320968
# 3           37.261774                60.003339                39.127179
# 4           38.042032                58.565890                39.621261
#
#    left_eye_outer_corner_x  left_eye_outer_corner_y  right_eye_inner_corner_x  \
# 0                73.130346                39.969997                 36.356571
# 1                70.722723                36.187166                 36.034723
# 2                70.984421                36.320968                 37.678105
# 3                72.314713                38.380967                 37.618643
# 4                72.515926                39.884466                 36.982380
#
#    right_eye_inner_corner_y  ...  nose_tip_x  nose_tip_y  mouth_left_corner_x  \
# 0                 37.389402  ...   44.420571   57.066803            61.195308
# 1                 34.361532  ...   48.206298   55.660936            56.421447
# 2                 36.320968  ...   47.557263   53.538947            60.822947
# 3                 38.754115  ...   51.885078   54.166539            65.598887
# 4                 39.094852  ...   43.299534   64.889521            60.671411
#
#    mouth_left_corner_y  mouth_right_corner_x  mouth_right_corner_y  \
# 0            79.970165             28.614496             77.388992
# 1            76.352000             35.122383             76.047660
# 2            73.014316             33.726316             72.732000
# 3            72.703722             37.245496             74.195478
# 4            77.523239             31.191755             76.997301
#
#    mouth_center_top_lip_x  mouth_center_top_lip_y  mouth_center_bottom_lip_x  \
# 0               43.312602               72.935459                  43.130707
# 1               46.684596               70.266553                  45.467915
# 2               47.274947               70.191789                  47.274947
# 3               50.303165               70.091687                  51.561183
# 4               44.962748               73.707387                  44.227141
#
#    mouth_center_bottom_lip_y
# 0                  84.485774
# 1                  85.480170
# 2                  78.659368
# 3                  78.268383
# 4                  86.871166
#
# [5 rows x 30 columns]

# %%
# Cleaing data
keypoints = keypoints.fillna(0)
num_missing_keypoints = keypoints.isnull().sum(axis = 1)
num_missing_keypoints
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7044    0
# 7045    0
# 7046    0
# 7047    0
# 7048    0
# Length: 7049, dtype: int64

# %%
new_features = features[keypoints.index.values, :, :, :] #Nums of rows,w, H, Channels
new_features = new_features / 255
keypoints.reset_index(inplace = True, drop = True)

# %%
plot_image_landmarks(new_features, keypoints, 3)

# %%
x_train, x_test, y_train, y_test = train_test_split(new_features, keypoints, test_size=0.2)

# %% [markdown]
# # **Our Model**

# %%
from tqdm.keras import TqdmCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, LeakyReLU, BatchNormalization
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD, Adam

# %% [markdown]
# **kernel_initializer** in Keras : Initializers define the way to set the initial random weights of Keras layers.
#
# **glorot_uniform()** : It draws samples from a uniform distribution within [-limit, limit] where limit is sqrt(6 / (fan_in + fan_out)) where fan_in is the number of input units in the weight tensor and fan_out is the number of output units in the weight tensor.
#
# We are using **the Mean Squared Error** as we are performing a regression task. A small learning rate is always good if you have a good amount of data

# %%
img_size = 96

# %%
model = Sequential()

model.add(Input(shape=(img_size, img_size, 1)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding="same",kernel_initializer=glorot_uniform()))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding="same",kernel_initializer=glorot_uniform()))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding="same",kernel_initializer=glorot_uniform()))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))  

model.add(Flatten())
model.add(Dense(256,kernel_initializer=glorot_uniform()))
model.add(LeakyReLU(alpha=0.1))

model.add(Dropout(0.5)) 

model.add(Dense(64,kernel_initializer=glorot_uniform()))
model.add(LeakyReLU(alpha=0))

model.add(Dense(30,kernel_initializer=glorot_uniform()))

model.summary()
model.compile(loss='mean_squared_error', optimizer=Adam(), metrics=['mean_squared_error'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 96, 96, 1)         4
# _________________________________________________________________
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 96, 96, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 48, 48, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 24, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4718848
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                1950
# =================================================================
# Total params: 4,830,306
# Trainable params: 4,830,112
# Non-trainable params: 194
# _________________________________________________________________

# %%
BATCH_SIZE = 100
EPOCHS = 150

# %% [markdown]
# # **Training Model**

# %%
history = model.fit(
    x_train, y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(x_test, y_test),
    shuffle=True,
    verbose=1,
)
# Out:
# Epoch 1/150
# 57/57 [==============================] - 9s 40ms/step - loss: 725.2604 - mean_squared_error: 725.2605 - val_loss: 907.8390 - val_mean_squared_error: 907.8390
# Epoch 2/150
# 57/57 [==============================] - 2s 27ms/step - loss: 321.6148 - mean_squared_error: 321.6148 - val_loss: 667.7061 - val_mean_squared_error: 667.7062
# Epoch 3/150
# 57/57 [==============================] - 2s 27ms/step - loss: 232.7483 - mean_squared_error: 232.7483 - val_loss: 697.6115 - val_mean_squared_error: 697.6115
# Epoch 4/150
# 57/57 [==============================] - 2s 28ms/step - loss: 198.3283 - mean_squared_error: 198.3283 - val_loss: 801.0239 - val_mean_squared_error: 801.0239
# Epoch 5/150
# 57/57 [==============================] - 2s 27ms/step - loss: 173.5156 - mean_squared_error: 173.5156 - val_loss: 759.8993 - val_mean_squared_error: 759.8993
# Epoch 6/150
# 57/57 [==============================] - 2s 27ms/step - loss: 177.0535 - mean_squared_error: 177.0535 - val_loss: 848.4068 - val_mean_squared_error: 848.4068
# Epoch 7/150
# 57/57 [==============================] - 2s 27ms/step - loss: 152.1893 - mean_squared_error: 152.1893 - val_loss: 625.9668 - val_mean_squared_error: 625.9668
# Epoch 8/150
# 57/57 [==============================] - 2s 27ms/step - loss: 136.9965 - mean_squared_error: 136.9965 - val_loss: 611.0057 - val_mean_squared_error: 611.0057
# Epoch 9/150
150
# 57/57 [==============================] - 2s 27ms/step - loss: 20.4572 - mean_squared_error: 20.4572 - val_loss: 129.0732 - val_mean_squared_error: 129.0732
# Epoch 115/150
# 57/57 [==============================] - 2s 27ms/step - loss: 21.8028 - mean_squared_error: 21.8028 - val_loss: 141.4231 - val_mean_squared_error: 141.4231
# Epoch 116/150
# 57/57 [==============================] - 2s 27ms/step - loss: 17.7750 - mean_squared_error: 17.7750 - val_loss: 135.5610 - val_mean_squared_error: 135.5610
# Epoch 117/150
# 57/57 [==============================] - 2s 28ms/step - loss: 18.7579 - mean_squared_error: 18.7579 - val_loss: 138.3190 - val_mean_squared_error: 138.3190
# Epoch 118/150
# 57/57 [==============================] - 2s 27ms/step - loss: 18.2389 - mean_squared_error: 18.2389 - val_loss: 126.8708 - val_mean_squared_error: 126.8708
# Epoch 119/150
# 57/57 [==============================] - 2s 27ms/step - loss: 17.6152 - mean_squared_error: 17.6152 - val_loss: 138.6182 - val_mean_squared_error: 138.6182
# Epoch 120/150
# 57/57 [==============================] - 2s 27ms/step - loss: 20.2945 - mean_squared_error: 20.2945 - val_loss: 133.1537 - val_mean_squared_error: 133.1537
# Epoch 121/150
# 57/57 [==============================] - 2s 27ms/step - loss: 17.0882 - mean_squared_error: 17.0882 - val_loss: 126.8794 - val_mean_squared_error: 126.8794
# Epoch 122/150
# 57/57 [==============================] - 2s 27ms/step - loss: 17.0849 - mean_squared_error: 17.0849 - val_loss: 127.1744 - val_mean_squared_error: 127.1744
# Epoch 123/150
# 57/57 [==============================] - 2s 27ms/step - loss: 18.1165 - mean_squared_error: 18.1165 - val_loss: 138.2655 - val_mean_squared_error: 138.2655
# Epoch 124/150
# 57/57 [==============================] - 2s 32ms/step - loss: 17.5508 - mean_squared_error: 17.5508 - val_loss: 130.9510 - val_mean_squared_error: 130.9510
# Epoch 125/150
# 57/57 [==============================] - 2s 27ms/step - loss: 16.9955 - mean_squared_error: 16.9955 - val_loss: 134.3304 - val_mean_squared_error: 134.3304
# Epoch 126/150
# 57/57 [==============================] - 2s 27ms/step - loss: 18.3725 - mean_squared_error: 18.3725 - val_loss: 131.4478 - val_mean_squared_error: 131.4478
# Epoch 127/150
# 57/57 [==============================] - 2s 27ms/step - loss: 16.9408 - mean_squared_error: 16.9408 - val_loss: 133.2605 - val_mean_squared_error: 133.2605
# Epoch 128/150
# 57/57 [==============================] - 2s 27ms/step - loss: 16.6186 - mean_squared_error: 16.6186 - val_loss: 148.8467 - val_mean_squared_error: 148.8467
# Epoch 129/150
# 57/57 [==============================] - 2s 27ms/step - loss: 17.6493 - mean_squared_error: 17.6493 - val_loss: 129.1098 - val_mean_squared_error: 129.1098
# Epoch 130/150
# 57/57 [==============================] - 2s 27ms/step - loss: 17.6531 - mean_squared_error: 17.6531 - val_loss: 138.4260 - val_mean_squared_error: 138.4260
# Epoch 131/150
# 57/57 [==============================] - 2s 28ms/step - loss: 17.6204 - mean_squared_error: 17.6204 - val_loss: 142.6467 - val_mean_squared_error: 142.6467
# Epoch 132/150
# 57/57 [==============================] - 2s 27ms/step - loss: 19.0450 - mean_squared_error: 19.0450 - val_loss: 138.2728 - val_mean_squared_error: 138.2728
# Epoch 133/150
# 57/57 [==============================] - 2s 27ms/step - loss: 19.5128 - mean_squared_error: 19.5128 - val_loss: 134.5812 - val_mean_squared_error: 134.5812
# Epoch 134/150
# 57/57 [==============================] - 2s 27ms/step - loss: 18.4780 - mean_squared_error: 18.4780 - val_loss: 134.5457 - val_mean_squared_error: 134.5457
# Epoch 135/150
# 57/57 [==============================] - 2s 27ms/step - loss: 17.6929 - mean_squared_error: 17.6929 - val_loss: 138.6184 - val_mean_squared_error: 138.6184
# Epoch 136/150
# 57/57 [==============================] - 2s 27ms/step - loss: 16.3146 - mean_squared_error: 16.3146 - val_loss: 125.1533 - val_mean_squared_error: 125.1533
# Epoch 137/150
# 57/57 [==============================] - 2s 27ms/step - loss: 19.5562 - mean_squared_error: 19.5562 - val_loss: 144.1113 - val_mean_squared_error: 144.1113
# Epoch 138/150
# 57/57 [==============================] - 2s 28ms/step - loss: 21.4374 - mean_squared_error: 21.4374 - val_loss: 132.2648 - val_mean_squared_error: 132.2648
# Epoch 139/150
# 57/57 [==============================] - 2s 27ms/step - loss: 15.9814 - mean_squared_error: 15.9814 - val_loss: 143.3594 - val_mean_squared_error: 143.3594
# Epoch 140/150
# 57/57 [==============================] - 2s 27ms/step - loss: 15.8439 - mean_squared_error: 15.8439 - val_loss: 154.0681 - val_mean_squared_error: 154.0680
# Epoch 141/150
# 57/57 [==============================] - 2s 27ms/step - loss: 19.3058 - mean_squared_error: 19.3058 - val_loss: 139.9378 - val_mean_squared_error: 139.9378
# Epoch 142/150
# 57/57 [==============================] - 2s 27ms/step - loss: 20.4570 - mean_squared_error: 20.4570 - val_loss: 157.5426 - val_mean_squared_error: 157.5426
# Epoch 143/150
# 57/57 [==============================] - 2s 27ms/step - loss: 18.2290 - mean_squared_error: 18.2290 - val_loss: 139.9768 - val_mean_squared_error: 139.9768
# Epoch 144/150
# 57/57 [==============================] - 2s 27ms/step - loss: 18.8947 - mean_squared_error: 18.8947 - val_loss: 136.8787 - val_mean_squared_error: 136.8787
# Epoch 145/150
# 57/57 [==============================] - 2s 31ms/step - loss: 17.2966 - mean_squared_error: 17.2966 - val_loss: 131.9816 - val_mean_squared_error: 131.9816
# Epoch 146/150
# 57/57 [==============================] - 2s 27ms/step - loss: 18.0312 - mean_squared_error: 18.0312 - val_loss: 136.0619 - val_mean_squared_error: 136.0619
# Epoch 147/150
# 57/57 [==============================] - 2s 27ms/step - loss: 18.6123 - mean_squared_error: 18.6123 - val_loss: 145.8155 - val_mean_squared_error: 145.8155
# Epoch 148/150
# 57/57 [==============================] - 2s 27ms/step - loss: 17.3086 - mean_squared_error: 17.3086 - val_loss: 141.3257 - val_mean_squared_error: 141.3257
# Epoch 149/150
# 57/57 [==============================] - 2s 27ms/step - loss: 17.1677 - mean_squared_error: 17.1677 - val_loss: 140.3289 - val_mean_squared_error: 140.3289
# Epoch 150/150
# 57/57 [==============================] - 2s 27ms/step - loss: 17.4632 - mean_squared_error: 17.4632 - val_loss: 131.9221 - val_mean_squared_error: 131.9221

# %%
plt.plot(history.history['mean_squared_error'], label='MSE (training data)')
plt.plot(history.history['val_mean_squared_error'], label='MSE (validation data)')
plt.title('MSE for Facial keypoints')
plt.ylabel('MSE value')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # **Model Evaluation**

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[61.47106   , 33.967133  , 28.31444   , ..., 67.41089   ,
#         45.832905  , 76.56346   ],
#        [60.080452  , 35.42592   , 28.590086  , ...,  0.38893002,
#         43.816208  , 69.31655   ],
#        [59.303505  , 33.843132  , 26.923162  , ...,  1.3555219 ,
#         42.62105   , 69.140434  ],
#        ...,
#        [62.45228   , 37.662228  , 27.800837  , ..., 72.45894   ,
#         42.585903  , 81.54927   ],
#        [58.805405  , 32.29506   , 27.018658  , ..., -0.1316598 ,
#         46.351887  , 67.99064   ],
#        [59.97804   , 38.484013  , 28.447556  , ...,  1.2138    ,
#         40.236374  , 71.83322   ]], dtype=float32)

# %%
def plot_img_preds(images, truth, pred, index):
    plt.imshow(images[index, :, :, 0], cmap = 'gray')
    
    t = np.array(truth)[index]
    plt.scatter(t[0::2], t[1::2], c = 'y')
    
    p = pred[index, :]
    plt.scatter(p[0::2], p[1::2], c = 'r')
    
    plt.show()

# %%
plot_img_preds(x_test, y_test, y_pred, 3)

# %%
plot_img_preds(x_test, y_test, y_pred, 18)
